# %% [markdown]
# # Summer Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv("summer.csv")

# %% [markdown]
# # 1. In how many cities Summer Olympics is held so far?

# %%
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# # 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
r = df[df['Medal'] == 'Gold']
data = []

for sport in r['Sport'].unique():
    data.append([sport, len(r[r['Sport']  == sport])])
    
data = pd.DataFrame(data, columns = ['Sports','Gold Medals'])
data = data.sort_values(by = 'Gold Medals', ascending = False).head()
data.plot(x='Sports',y='Gold Medals', kind = 'bar',figsize=(5,5))
print(data)
# Out:
#         Sports  Gold Medals
# 0     Aquatics         1421
# 1    Athletics         1215
# 17      Rowing          890
# 4   Gymnastics          820
# 3      Fencing          552

# %% [markdown]
# # 3. Which sport is having most number of medals so far? (Top 5)

# %%
data = []

for sport in df['Sport'].unique():
    data.append([sport, len(df[df['Sport']  == sport])])
    
data = pd.DataFrame(data, columns = ['Sports','Medals'])
data = data.sort_values(by = 'Medals', ascending = False).head()
data.plot(x='Sports',y='Medals', kind = 'bar',figsize=(5,5))
print(data)
# Out:
#         Sports  Medals
# 0     Aquatics    4170
# 1    Athletics    3638
# 17      Rowing    2667
# 4   Gymnastics    2307
# 3      Fencing    1613

# %% [markdown]
# # 4. Which player has won most number of medals? (Top 5)

# %%
data = []

for ath in df['Athlete'].unique():
    data.append([ath, len(df[df['Athlete']  == ath])])
    
data = pd.DataFrame(data, columns = ['Athlete','Medals'])
data = data.sort_values(by = 'Medals', ascending = False).head()
data.plot(x='Athlete',y='Medals', kind = 'bar',figsize=(5,5))
print(data)
# Out:
#                     Athlete  Medals
# 18640       PHELPS, Michael      22
# 7197       LATYNINA, Larisa      18
# 9948     ANDRIANOV, Nikolay      15
# 6591           ONO, Takashi      13
# 5103   MANGIAROTTI, Edoardo      13

# %% [markdown]
# # 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
r = df[df['Medal'] == 'Gold']
data = []

for ath in r['Athlete'].unique():
    data.append([ath, len(r[r['Athlete']  == ath])])
    
data = pd.DataFrame(data, columns = ['Athlete','Gold Medals'])
data = data.sort_values(by = 'Gold Medals', ascending = False).head()
data.plot(x='Athlete',y='Gold Medals', kind = 'bar',figsize=(5,5))
print(data)
# Out:
#                Athlete  Gold Medals
# 6851   PHELPS, Michael           18
# 3320       SPITZ, Mark            9
# 2714  LATYNINA, Larisa            9
# 4630       LEWIS, Carl            9
# 907       NURMI, Paavo            9

# %% [markdown]
# # 6. In which year India won first Gold Medal in Summer Olympics?

# %%
con = r[r['Country']=='IND']
data = []

for year in con['Year'].unique():
    data.append([year, len(con[con['Year']  == year])])
    
data = pd.DataFrame(data, columns = ['year','IND'])
data = data.sort_values(by = 'year', ascending = True).head(1)

print(data['year'])
# Out:
# 0    1928
# Name: year, dtype: int64

# %% [markdown]
# # 7. Which event is most popular in terms on number of players? (Top 5)

# %%
data = []

for event in df['Event'].unique():
    data.append([event, len(df[df['Event']  == event])])
    
data = pd.DataFrame(data, columns = ['event','Players'])
data = data.sort_values(by = 'Players', ascending = False).head()
data.plot(x='event',y='Players', kind = 'bar',figsize=(5,5))
print(data)
# Out:
#                 event  Players
# 80           Football     1497
# 176            Hockey     1422
# 138  Team Competition     1147
# 327        Basketball     1012
# 337          Handball      973

# %% [markdown]
# # 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
r = df[df['Medal'] == 'Gold']
f = r[r['Gender'] == 'Women']
data = []

for sport in f['Sport'].unique():
    data.append([sport, len(f[f['Sport']  == sport])])
    
data = pd.DataFrame(data, columns = ['Sports','Females'])
data = data.sort_values(by = 'Females', ascending = False).head()
data.plot(x='Sports',y='Females', kind = 'bar',figsize=(5,5))
print(data)
# Out:
#         Sports  Females
# 4     Aquatics      589
# 7    Athletics      389
# 8   Gymnastics      268
# 14      Rowing      217
# 11  Volleyball      166
